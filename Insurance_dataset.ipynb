# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitkumarsoam01/ankitkumarsoam01.github.io/blob/main/Insurance_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Insurance Dataset**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
dataset= pd.read_csv('insurance.csv')

# %%
dataset.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
dataset.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# There are no null values in any column.

# %%
insurance_Nchild=dataset[dataset['children']==0]
insurance_age_price=insurance_Nchild[['age','charges']]

# %%
insurance_age_price.head()
# Out:
#    age      charges
# 0   19  16884.92400
# 3   33  21984.47061
# 4   32   3866.85520
# 5   31   3756.62160
# 9   60  28923.13692

# %%
sns.lmplot(x='age',y='charges', data=insurance_age_price,order=2)

# %%
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = np.array(insurance_age_price['age']).reshape(-1, 1)
y = np.array(insurance_age_price['charges']).reshape(-1, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Splitting the data into training and testing data
regr = LinearRegression()

regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.15106415868596945

# %% [markdown]
# The low accuracy score of our model suggests that our regressive model has not fit very well with the existing data. This suggests that our data is not suitable for linear regression. But sometimes, a dataset may accept a linear regressor if we consider only a part of it.
